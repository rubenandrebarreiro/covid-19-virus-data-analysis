# %%
from __future__ import print_function

# %%
from datetime import datetime

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.tile_providers import Vendors, get_provider
from bokeh.models import ColumnDataSource

# %%
from ast import literal_eval

# %%
import sys

# %%
import os

# %%
import os.path as path

# %%
import matplotlib.pyplot as mplplt
# %matplotlib inline

# %%
import pickle as pkl

# %%
import pandas as pd

# %%
import numpy as np

# %%
def merc(coords):
    Coordinates = literal_eval(coords)
    
    lat = Coordinates[0]
    lon = Coordinates[1]
    
    r_major = 6378137.000
    x = r_major * math.radians(lon)
    
    scale = (x/lon)
    
    y = (180.0/math.pi) * ( math.log(math.tan(math.pi/4.0 + lat * (math.pi/180.0)/2.0)) ) * scale
    
    return (x, y)

# %%
#supporting function
def make_tuple_str(x, y):
    t = (x, y)
    
    return str(t)

# %%
# Read with pandas
datafile = pd.read_csv('../datasets/time_series-ncov-Confirmed.csv')

# %%
datafile
# Out:
#       Province/State Country/Region       Lat      Long        Date  \
# 0         #adm1+name  #country+name  #geo+lat  #geo+lon       #date
# 1                NaN    Afghanistan        33        65  2020-03-10
# 2                NaN    Afghanistan        33        65  2020-03-09
# 3                NaN    Afghanistan        33        65  2020-03-08
# 4                NaN    Afghanistan        33        65  2020-03-07
# ...              ...            ...       ...       ...         ...
# 16999            NaN       Viet Nam        16       108  2020-01-26
# 17000            NaN       Viet Nam        16       108  2020-01-25
# 17001            NaN       Viet Nam        16       108  2020-01-24
# 17002            NaN       Viet Nam        16       108  2020-01-23
# 17003            NaN       Viet Nam        16       108  2020-01-22
#
#                               Value
# 0      #affected+infected+value+num
# 1                                 5
# 2                                 4
# 3                                 4
# 4                                 1
# ...                             ...
# 16999                             2
# 17000                             2
# 17001                             2
# 17002                             2
# 17003                             0
#
# [17004 rows x 6 columns]

# %%
dataframe_coords_by_date = datafile[['Country/Region', 'Province/State', 'Lat', 'Long', 'Date', 'Value']]

# %%
dataframe_coords_by_date
# Out:
#       Country/Region Province/State       Lat      Long        Date  \
# 0      #country+name     #adm1+name  #geo+lat  #geo+lon       #date
# 1        Afghanistan            NaN        33        65  2020-03-10
# 2        Afghanistan            NaN        33        65  2020-03-09
# 3        Afghanistan            NaN        33        65  2020-03-08
# 4        Afghanistan            NaN        33        65  2020-03-07
# ...              ...            ...       ...       ...         ...
# 16999       Viet Nam            NaN        16       108  2020-01-26
# 17000       Viet Nam            NaN        16       108  2020-01-25
# 17001       Viet Nam            NaN        16       108  2020-01-24
# 17002       Viet Nam            NaN        16       108  2020-01-23
# 17003       Viet Nam            NaN        16       108  2020-01-22
#
#                               Value
# 0      #affected+infected+value+num
# 1                                 5
# 2                                 4
# 3                                 4
# 4                                 1
# ...                             ...
# 16999                             2
# 17000                             2
# 17001                             2
# 17002                             2
# 17003                             0
#
# [17004 rows x 6 columns]

# %%
dataframe_coords_1st_week_january = dataframe_coords_by_date[ (dataframe_coords_by_date['Date'] > '2020-01-01') & (dataframe_coords_by_date['Date'] <= '2020-01-07')]

# %%
dataframe_coords_1st_week_january
# Out:
# Empty DataFrame
# Columns: [Country/Region, Province/State, Lat, Long, Date, Value]
# Index: []

# %%
dataframe_coords_2nd_week_january = dataframe_coords_by_date[ (dataframe_coords_by_date['Date'] > '2020-01-08') & (dataframe_coords_by_date['Date'] <= '2020-01-14')]

# %%
dataframe_coords_2nd_week_january
# Out:
# Empty DataFrame
# Columns: [Country/Region, Province/State, Lat, Long, Date, Value]
# Index: []

# %%
dataframe_coords_3rd_week_january = dataframe_coords_by_date[ (dataframe_coords_by_date['Date'] > '2020-01-15') & (dataframe_coords_by_date['Date'] <= '2020-01-21')]

# %%
dataframe_coords_3rd_week_january
# Out:
# Empty DataFrame
# Columns: [Country/Region, Province/State, Lat, Long, Date, Value]
# Index: []

# %%
dataframe_coords_4th_week_january = dataframe_coords_by_date[ (dataframe_coords_by_date['Date'] > '2020-01-22') & (dataframe_coords_by_date['Date'] <= '2020-01-28')]

# %%
dataframe_coords_4th_week_january
# Out:
#       Country/Region Province/State Lat Long        Date Value
# 43       Afghanistan            NaN  33   65  2020-01-28     0
# 44       Afghanistan            NaN  33   65  2020-01-27     0
# 45       Afghanistan            NaN  33   65  2020-01-26     0
# 46       Afghanistan            NaN  33   65  2020-01-25     0
# 47       Afghanistan            NaN  33   65  2020-01-24     0
# ...              ...            ...  ..  ...         ...   ...
# 16998       Viet Nam            NaN  16  108  2020-01-27     2
# 16999       Viet Nam            NaN  16  108  2020-01-26     2
# 17000       Viet Nam            NaN  16  108  2020-01-25     2
# 17001       Viet Nam            NaN  16  108  2020-01-24     2
# 17002       Viet Nam            NaN  16  108  2020-01-23     2
#
# [2082 rows x 6 columns]

# %%
dataframe_coords_4th_week_january = dataframe_coords_4th_week_january[dataframe_coords_4th_week_january['Value'] > '0']

# %%
dataframe_coords_4th_week_january
# Out:
#       Country/Region   Province/State       Lat      Long        Date Value
# 386        Australia  New South Wales  -33.8688  151.2093  2020-01-28     4
# 387        Australia  New South Wales  -33.8688  151.2093  2020-01-27     4
# 388        Australia  New South Wales  -33.8688  151.2093  2020-01-26     3
# 631        Australia         Victoria  -37.8136  144.9631  2020-01-28     1
# 632        Australia         Victoria  -37.8136  144.9631  2020-01-27     1
# ...              ...              ...       ...       ...         ...   ...
# 16998       Viet Nam              NaN        16       108  2020-01-27     2
# 16999       Viet Nam              NaN        16       108  2020-01-26     2
# 17000       Viet Nam              NaN        16       108  2020-01-25     2
# 17001       Viet Nam              NaN        16       108  2020-01-24     2
# 17002       Viet Nam              NaN        16       108  2020-01-23     2
#
# [274 rows x 6 columns]

# %%
dataframe_coords_4th_week_january.groupby(['Lat', 'Long'], sort=True)['Country/Region', 'Province/State', 'Value'].max()
# Out:
#                          Country/Region       Province/State Value
# Lat      Long
# -33.8688 151.2093             Australia      New South Wales     4
# -37.8136 144.9631             Australia             Victoria     1
# 1.2833   103.8333             Singapore                  NaN     7
# 11.55    104.9167              Cambodia                  NaN     1
# 15       101                   Thailand                  NaN     8
# 16       108                   Viet Nam                  NaN     2
# 19.1959  109.7453        Mainland China               Hainan     8
# 2.5      112.5                 Malaysia                  NaN     4
# 22.1667  113.55               Macao SAR                Macau     7
# 22.3     114.2            Hong Kong SAR            Hong Kong     8
# 23.3417  113.4244        Mainland China            Guangdong    78
# 23.7     121        Taipei and environs               Taiwan     8
# 23.8298  108.7881        Mainland China              Guangxi    51
# 24.974   101.487         Mainland China               Yunnan     5
# 26.0789  117.9874        Mainland China               Fujian    80
# 26.8154  106.8748        Mainland China              Guizhou     9
# 27.6104  111.7088        Mainland China                Hunan     9
# 27.614   115.7221        Mainland China              Jiangxi    72
# 28.1667  84.25                    Nepal                  NaN     1
# 29.1832  120.0934        Mainland China             Zhejiang    62
# 30.0572  107.874         Mainland China            Chongqing     9
# 30.6171  102.7103        Mainland China              Sichuan    90
# 30.9756  112.2707        Mainland China                Hubei   761
# 31.202   121.4491        Mainland China             Shanghai    66
# 31.8257  117.2264        Mainland China                Anhui     9
# 32.9711  119.455         Mainland China              Jiangsu     9
# 33.2918  -112.4291                   US  Maricopa County, AZ     1
# 33.7879  -117.8531                   US    Orange County, CA     1
# 33.88202 113.614         Mainland China                Henan     9
# 34.0522  -118.2437                   US      Los Angeles, CA     1
# 35.1917  108.8701        Mainland China              Shaanxi     5
# 35.7452  95.9956         Mainland China              Qinghai     6
# 36       128          Republic of Korea                  NaN     4
#          138                      Japan                  NaN     7
# 36.0611  103.8343        Mainland China                Gansu     7
# 36.3427  118.1498        Mainland China             Shandong    95
# 37.2692  106.1655        Mainland China              Ningxia     7
# 37.5777  112.2922        Mainland China               Shanxi     9
# 38.0428  114.5149        Mainland China                Hebei     8
# 39.3054  117.323         Mainland China              Tianjin     8
# 40.1824  116.4142        Mainland China              Beijing    91
# 41.1129  85.2401         Mainland China             Xinjiang     5
# 41.2956  122.6085        Mainland China             Liaoning     4
# 41.7377  -87.6976                    US      Cook County, IL     1
# 43.6661  126.1923        Mainland China                Jilin     8
# 44.0935  113.9448        Mainland China       Inner Mongolia     7
# 47       2                       France                  NaN     4
# 47.6062  -122.3321                   US      King County, WA     1
# 47.862   127.7615        Mainland China         Heilongjiang     9
# 49.2827  -123.1207               Canada     British Columbia     1
# 51       9                      Germany                  NaN     4
# 51.2538  -85.3232                Canada              Ontario     1
# 7        81                   Sri Lanka                  NaN     1

# %%
dataframe_coords_4th_week_january_index = dataframe_coords_4th_week_january.groupby(['Lat', 'Long'], sort=False)['Value'].transform(max) == dataframe_coords_4th_week_january['Value']

# %%
dataframe_coords_4th_week_january = dataframe_coords_4th_week_january[dataframe_coords_4th_week_january_index]

# %%
dataframe_coords_4th_week_january_index = dataframe_coords_4th_week_january.groupby(['Lat', 'Long'], sort=False)['Date'].transform(max) == dataframe_coords_4th_week_january['Date']

# %%
dataframe_coords_4th_week_january = dataframe_coords_4th_week_january[dataframe_coords_4th_week_january_index]

# %%
dataframe_coords_4th_week_january
# Out:
#             Country/Region       Province/State       Lat       Long  \
# 386              Australia      New South Wales  -33.8688   151.2093
# 631              Australia             Victoria  -37.8136   144.9631
# 1317              Cambodia                  NaN     11.55   104.9167
# 1464                Canada     British Columbia   49.2827  -123.1207
# 1513                Canada              Ontario   51.2538   -85.3232
# 2297                France                  NaN        47          2
# 2444               Germany                  NaN        51          9
# 2640         Hong Kong SAR            Hong Kong      22.3      114.2
# 3130                 Japan                  NaN        36        138
# 3522             Macao SAR                Macau   22.1667     113.55
# 3576        Mainland China                Anhui   31.8257   117.2264
# 4796   2020-01-28    90
# 4849   2020-01-24     8
# 4944   2020-01-27     5
# 4996   2020-01-24     5
# 5044   2020-01-25    62
# 5090   2020-01-28     4
# 5482   2020-01-28     1
# 6315   2020-01-28     4
# 6805   2020-01-28     7
# 7050   2020-01-28     1
# 7197   2020-01-28     8
# 7247   2020-01-27     8
# 8912   2020-01-28     1
# 11558  2020-01-28     1
# 11852  2020-01-28     1
# 12146  2020-01-28     1
# 13714  2020-01-28     1
# 16997  2020-01-28     2

# %%
def wgs84_to_web_mercator(dataframe, lon="Long", lat="Lat"):

    k = 6378137
    
    dataframe["x"] = dataframe[lon] * (k * np.pi/180.0)
    dataframe["y"] = np.log(np.tan((90 + dataframe[lat]) * np.pi/360.0)) * k

    return dataframe

# %%
dataframe_coords_4th_week_january = wgs84_to_web_mercator(dataframe_coords_4th_week_january)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#     967         try:
# --> 968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     126     if result is None:
# --> 127         result = _evaluate_standard(op, op_str, a, b)
#     128
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# TypeError: can't multiply sequence by non-int of type 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-e9da65b0e737> in <module>
# ----> 1 dataframe_coords_4th_week_january = wgs84_to_web_mercator(dataframe_coords_4th_week_january)
#
# <ipython-input-34-4c354ba10d41> in wgs84_to_web_mercator(dataframe, lon, lat)
#       3     k = 6378137
#       4
# ----> 5     dataframe["x"] = dataframe[lon] * (k * np.pi/180.0)
#       6     dataframe["y"] = np.log(np.tan((90 + dataframe[lat]) * np.pi/360.0)) * k
#       7
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#    1046
#    1047         with np.errstate(all="ignore"):
# -> 1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
#    1050             left, result, index=left.index, name=res_name, dtype=None
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#     968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
# --> 970             result = masked_arith_op(x, y, op)
#     971
#     972         return missing.dispatch_fill_zeros(op, x, y, result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in masked_arith_op(x, y, op)
#     462         if mask.any():
#     463             with np.errstate(all="ignore"):
# --> 464                 result[mask] = op(xrav[mask], y)
#     465
#     466     result, changed = maybe_upcast_putmask(result, ~mask, np.nan)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
dataframe_coords_4th_week_january_source = ColumnDataSource(data = dataframe_coords_4th_week_january)

# %%
dataframe_coords_4th_week_january_source

# %%
output_file("covid_19_virus_confirmed_geomapping_4th_week_january.html")

# %%
tile_provider = get_provider(Vendors.CARTODBPOSITRON)

# %%
# Range bounds supplied in web mercator coordinates
geo_plot = figure(x_range=(-9000000, 9000000), y_range=(-9000000, 9000000),
           sizing_mode='stretch_both')

# %%
geo_plot.circle(x='Long', y='Lat', source=dataframe_coords_4th_week_january_source, line_color='yellow', fill_color='red')

# %%
geo_plot.axis.visible = False

# %%
geo_plot.add_tile(tile_provider)

# %%
show(geo_plot)

# %%
dataframe_coords_5th_week_january = dataframe_coords_by_date[ (dataframe_coords_by_date['Date'] > '2020-01-29') & (dataframe_coords_by_date['Date'] <= '2020-02-04')]

# %%
dataframe_coords_5th_week_january

# %%
dataframe_coords_1st_week_february = dataframe_coords_by_date[ (dataframe_coords_by_date['Date'] > '2020-02-01') & (dataframe_coords_by_date['Date'] <= '2020-02-07')]

# %%
datafile['coords'] = datafile.apply(lambda x: make_tuple_str(x['Lat'], x['Long']), axis = 1)
datafile['coords_latitude'] = datafile['coords'].apply(lambda x: merc(x)[0])
datafile['coords_longitude'] = datafile['coords'].apply(lambda x: merc(x)[1])

# %%
output_file("covid_19_virus_confirmed_geomapping.html")

# %%
tile_provider = get_provider(Vendors.CARTODBPOSITRON)

# %%
# Range bounds supplied in web mercator coordinates
geo_plot = figure(x_range=(-9000000, 9000000), y_range=(-9000000, 9000000),
           sizing_mode='stretch_both',
           x_axis_type="mercator", y_axis_type="mercator")

# %%
geo_plot.add_tile(tile_provider)

# %%
show(geo_plot)
